# %%
import sys

# install dependencies
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: openai in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.26.2)
# Requirement already satisfied: gradio in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (3.16.2)
# Requirement already satisfied: langchain in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.0.69)
# Requirement already satisfied: datetime in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (5.0)
# Requirement already satisfied: yake in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: aiohttp in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from openai->-r requirements.txt (line 1)) (3.8.3)
# Requirement already satisfied: requests>=2.20 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from openai->-r requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: tqdm in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from openai->-r requirements.txt (line 1)) (4.64.1)
# Requirement already satisfied: numpy in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (1.21.5)
# Requirement already satisfied: httpx in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (0.23.3)
# Requirement already satisfied: aiofiles in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: pydub in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (0.25.1)
# Requirement already satisfied: altair>=4.2.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (4.2.0)
# Requirement already satisfied: typing-extensions in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (4.3.0)
# Requirement already satisfied: websockets>=10.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (10.4)
# Requirement already satisfied: markupsafe in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: markdown-it-py[linkify,plugins] in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: pandas in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: ffmpy in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: fsspec in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (2022.7.1)
# Requirement already satisfied: pillow in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (9.2.0)
# Requirement already satisfied: python-multipart in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (0.0.5)
# Requirement already satisfied: orjson in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (3.8.5)
# Requirement already satisfied: uvicorn in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (0.20.0)
# Requirement already satisfied: pycryptodome in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (3.16.0)
# Requirement already satisfied: matplotlib in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (3.5.2)
# Requirement already satisfied: pydantic in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (1.10.4)
# Requirement already satisfied: pyyaml in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (6.0)
# Requirement already satisfied: jinja2 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (2.11.3)
# Requirement already satisfied: fastapi in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from gradio->-r requirements.txt (line 2)) (0.89.1)
# Requirement already satisfied: SQLAlchemy<2,>=1 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from langchain->-r requirements.txt (line 3)) (1.4.39)
# Requirement already satisfied: pytz in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from datetime->-r requirements.txt (line 4)) (2022.1)
# Requirement already satisfied: zope.interface in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from datetime->-r requirements.txt (line 4)) (5.4.0)
# Requirement already satisfied: jellyfish in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from yake->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: tabulate in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from yake->-r requirements.txt (line 5)) (0.8.10)
# Requirement already satisfied: segtok in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from yake->-r requirements.txt (line 5)) (1.5.11)
# Requirement already satisfied: click>=6.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from yake->-r requirements.txt (line 5)) (8.0.4)
# Requirement already satisfied: networkx in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from yake->-r requirements.txt (line 5)) (2.8.4)
# Requirement already satisfied: toolz in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.2.0->gradio->-r requirements.txt (line 2)) (0.11.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.2.0->gradio->-r requirements.txt (line 2)) (4.16.0)
# Requirement already satisfied: entrypoints in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.2.0->gradio->-r requirements.txt (line 2)) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from pandas->gradio->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai->-r requirements.txt (line 1)) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai->-r requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy<2,>=1->langchain->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai->-r requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai->-r requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai->-r requirements.txt (line 1)) (21.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai->-r requirements.txt (line 1)) (4.0.2)
# Requirement already satisfied: starlette==0.22.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from fastapi->gradio->-r requirements.txt (line 2)) (0.22.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from starlette==0.22.0->fastapi->gradio->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from httpx->gradio->-r requirements.txt (line 2)) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from httpx->gradio->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: sniffio in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from httpx->gradio->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py[linkify,plugins]->gradio->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: mdit-py-plugins in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py[linkify,plugins]->gradio->-r requirements.txt (line 2)) (0.3.3)
# Requirement already satisfied: linkify-it-py~=1.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py[linkify,plugins]->gradio->-r requirements.txt (line 2)) (1.0.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->gradio->-r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->gradio->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->gradio->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->gradio->-r requirements.txt (line 2)) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->gradio->-r requirements.txt (line 2)) (4.25.0)
# Requirement already satisfied: six>=1.4.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from python-multipart->gradio->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: regex in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from segtok->yake->-r requirements.txt (line 5)) (2022.7.9)
# Requirement already satisfied: h11>=0.8 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from uvicorn->gradio->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: setuptools in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from zope.interface->datetime->-r requirements.txt (line 4)) (63.4.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->-r requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: uc-micro-py in /Users/cbandi/opt/anaconda3/lib/python3.9/site-packages (from linkify-it-py~=1.0->markdown-it-py[linkify,plugins]->gradio->-r requirements.txt (line 2)) (1.0.1)

# %%
# imports
import os
import openai
import gradio as gr
from langchain import OpenAI, SQLDatabase, SQLDatabaseChain
import datetime
import sqlite3
import pandas as pd
import uuid
import subprocess
import re
import yake
import requests
import xmltodict

# %%
# Functions for UI

def set_openai_api_key(api_key, openai_api_key, pal_chain):
    if api_key:
        openai_api_key = api_key
        os.environ["OPENAI_API_KEY"] = api_key
        
        # Connect to database
        db = SQLDatabase.from_uri("sqlite:///./testAg.db")
        llm = OpenAI(temperature=0)
        db_chain = SQLDatabaseChain(llm=llm, database=db, verbose=True)

        os.environ["OPENAI_API_KEY"] = ""

        return openai_api_key, db_chain
    

def openai_create(prompt, openai_api_key):
    print("prompt: " + prompt)

    # We use temperature of 0.0 because it gives the most predictable, factual answer (i.e. avoids hallucination).
    os.environ["OPENAI_API_KEY"] = openai_api_key
    response = openai.Completion.create(
        model="text-davinci-003",
        prompt=prompt,
        temperature=0.0,
        max_tokens=300,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )
    os.environ["OPENAI_API_KEY"] = ""

    return response.choices[0].text

def calc_gpt_only(prompt, openai_api_key):
    if not openai_api_key or openai_api_key == "":
        return "<pre>Please paste your OpenAI API key</pre>"

    f = open("history.txt", "a")
    f.write(prompt + ";\n")
    
    answer = openai_create(prompt + "\n", openai_api_key)
    f.write(answer + "\n")

    html = "<pre>" + answer + "</pre>"
    return html

def calc_gpt_sql(prompt, db_chain):
    if not db_chain:
        return "<pre>Please paste your OpenAI API key</pre>"

    f = open("history.txt", "a")
    f.write(prompt + ";\n")
    
    res = db_chain.run(prompt)
    f.write(res + "\n")
    html = "<pre>" + res + "</pre>"
    return html


# David (7 Feb) Update get_history function
MAX_LINES_STOP = 10

def get_history(max_lines=MAX_LINES_STOP):
    res = ""
    f = open("history.txt", "r")
    lines = f.readlines()
    for index in range(len(lines)):
        if lines[index][-2:] == ";\n":
            res += "<li> Question: " + lines[index][:-2] + "</li>"
            currentIndex = index+3
            counter = 0
            answer = ""
            while counter < max_lines:
                if lines[currentIndex][-2:] == ".\n":
                    break
                answer += lines[currentIndex]
                currentIndex += 1
                counter += 1
            res += "<li> Answer: " + answer + "</li>"
    return "<ul>" + res + "</ul>"

def clear_history():
    f = open("history.txt", "w")
    f.close()
    return "<h3> History Cleared! </h3>"

# %%
# Wolfram Alpha Short request API
def categorization (query, openai_api_key):
    categories = ["Recipe questions","Dishes nutrition questions","Ingredient nutrient questions","Food comparison questions","Food substition questions","Personal diet questions"]
    category = openai_create('"' + query + '" Which one of the following categories does this question belong to: ' + ','.join(categories), openai_api_key)
    return (category)


# Wolfram Alpha Full request API

WOLF_ALPHA_APPID = 'JTAHAK-GJKLKJEX88'
BASE_URL = 'http://api.wolframalpha.com/v2/query?appid=' + WOLF_ALPHA_APPID

def wolfAlphaFullQuery(query):
    split_query = query.split(' ')
    formatted_query = ''
    for i in range(len(split_query)):
        if i == len(split_query)-1:
            formatted_query += split_query[i] + '%20'
            continue
        formatted_query += split_query[i] + '+'
    url = BASE_URL + '&input=' + formatted_query
    response = requests.get(url)
    print('Status Code: ' + str(response.status_code) + '\n')
    if int(response.status_code) != 200:
        return "Could not retrieve answer!"
    result = response.content.decode()
    parsedRes = xmltodict.parse(result)
    if parsedRes['queryresult']['@success'] == 'false':
        return "Could not retrieve answer! (Query Failed)"
    resArr = []
    for obj in parsedRes['queryresult']['pod']:
        if int(obj['@numsubpods']) == 1:
            resArr.append(obj['subpod']['plaintext'])
        else:
            for i in obj['subpod']:
                resArr.append(i['plaintext'])
    strResult = ""
    for i in resArr:
        if type(i) == str:
            strResult += i
    return strResult


def getWolfAlphaAnswers(questions):
    question_arr = questions.split("\n")
    result = ''
    for i in question_arr:
        if len(i) < 3:
            continue
        result += i + ' ' + wolfAlphaFullQuery(i) + '\n'
    return result

def wolfAlphaGpt3Complete(query, open_ai_key):
    f = open('history.txt',"a")
    
    p1a = open('promptfa.txt','r')
    p1a = p1a.read()
    p1b_norm = open ('prompt1b_copy.txt','r')
    p1b_norm = p1b_norm.read()    
    firstprompt = str (p1a) + query + str(p1b_norm)
    questions = openai_create (firstprompt, open_ai_key)
    
    out1 = getWolfAlphaAnswers(questions)
    secondprompt = 'Based on the data, ' + query + 'Data: ' + out1 + '. Please include the data and show the calculations to support your answer'
    out2 = openai_create (secondprompt, open_ai_key)
    f.write (secondprompt + ";\n")
    f.write (out2 + "\n")
    #print ("prompt: " + firstprompt)
    print (out1)
    print (out2)
    return out2

# query = wolfAlphaQuery("1 radish, 1 artichoke, 1 avocado, 1 carrot")    
# print(query)

# %%
# Pseduocode for filecheck

# Keyword Extracter
    # input is a sentence (based on the prompt)
    # Identifies the key words in the prompt
    # Returns a list of keywords (top 5)
    
# file_column
    # Input list of files
    # Pulls out the columns 
    # output dictionary with file as the key and columns as the value
    
# file matching
    # Input list of keywords and file columns
    # Based on the above output, matches the keywords to the relevant files <- if the keywordsa are is in the file's column it is added
    # Returns dictionary of relevant file (key) and the columns (value)

# Rel_files
    # Input prompt and list of files
    # Runs keyword extracter
    # Runs file_column
    # runs file matching with the keyword extracter and file column
    # Outputs a prompt that specifies which files to use based on the number of relevant files

# %%
# Getting the relevant files

# Add more files here 


def keyword_extracter (prompt):
    keyword_list = []
    kw_extractor = yake.KeywordExtractor(top=5, stopwords=None)
    keywords = kw_extractor.extract_keywords(prompt)
    for kw, v in keywords:
        keyword_list.append(str(kw))
    return keyword_list 

# Identifying columns from a list of files
def file_columns (file_list):
    file_col = {}
    for file in file_list:
        if ".csv" in file:
            df = pd.read_csv(file)
            column_names = list(df.columns.values)
            file_col[file] = column_names
            continue
        elif ".xlsx" in file:
            df = pd.read_excel(file)
            column_names = list(df.columns.values)
            file_col[file] = column_names
        return file_col

# Matching keywords to the column names of files
def file_matching (keyword_list, file_col):
    relevant_files = {}
    for keyw in keyword_list:    
        for file, columns in file_col.items(): 
            for col in columns:
                if keyw.lower() in col.lower():
                    if file not in relevant_files:
                        relevant_files [file] = file_col[file]
    return relevant_files

# Running all of the above <- returns list of relevant files
def rel_files (prompt, file_list):
    keyword_list = keyword_extracter(prompt)
    file_col = file_columns (file_list)
    file_relevant = file_matching (keyword_list, file_col)
    # Print if file_relevant is just one file
    if len(file_relevant) == 0:
        return ". "
    if len (file_relevant) ==1: 
        return (". Use " + '"' + str(list(file_relevant.items())[0][0]) + '" ' + " to answer this. It contains the columns: " + str(list(file_relevant.items())[0][1]) + '. ') 
    # Adding on to the string when there are more than one relevant files
    if len (file_relevant) > 1: 
        string_output = ". Use some of the following files to answer this: "
        final_string = string_output
        for file, cols in file_relevant.items():
            additional_string = '"' + str (file) + '" ' + "which contains the following columns: " + ', '.join(cols) + ', '
            final_string += additional_string
        return (final_string[:-2] + '. ')

# %%
## R code

gpt_only_prompt = ""

def openai_create (prompt, openai_api_key):
    response = openai.Completion.create (
    model="text-davinci-003",
    prompt=prompt,
    temperature=0.0,
    max_tokens=300,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )
    os.environ["OPENAI_API_KEY"] = ""
    return response.choices[0].text

def gpt_code (coderequest, openai_api_key):
    # David added installation of libaraies 2 Feb
#     filerequest = "Use AgSensorDataF037-renamed.csv to answer this. The file has columns of data named Time,Temperature,Humidity,Pressure,Soil_Moisture,Wind_Speed,Wind_Direction,Ambient_Temperature,Ambient_Humidity,Battery. Generate a code in R language to analyze it. Output only R code, ignore pretext and start with loading of libraries. Do not plot anything. The code should print out the answer. Install all the packages needed, choose the repository from http://cran.us.r-project.org."
#     filerequest = "Generate a code in R language to analyze it. Output only R code, ignore pretext and start with loading of libraries. Do not plot anything. The code should print out the answer. Install all the packages needed, choose the repository from http://cran.us.r-project.org."
    # David (7 Feb) Add do not install packages if already installed
    
    # Extracting the keywords from the prompt
    file_list = ["AgSensorDataF037-renamed.csv","demoData.xlsx"]
    filerequest = rel_files(coderequest,file_list)
    postrequest = "Generate a code in R language to analyze it. Output only R code, ignore pretext and start with loading of libraries. Do not plot anything. The code should print out the answer. Install packages if needed, choose the repository from http://cran.us.r-project.org. Do not install packages if already installed."
    print (coderequest + filerequest + postrequest)

    # Talk more about the data ie what columns they have
    answer = openai_create (coderequest + filerequest + postrequest, openai_api_key)
    # data = pd.read_excel(file)
    print("coding question: " + coderequest)
    print("code: " + answer)
    return answer

def rewrite_code_prompt(filename):
    code = ""
    f = open(filename, "r")
    for i in f:
        code.append(i)
    prompt = "Rewrite the following R code to print the result" + code # Add print only r code
    return prompt

def install_package_prompt(filename, package):
    code = ""
    f = open(filename, "r")
    for i in f:
        code.append(i)
    prompt = "Install the R package " + package + " and run" + code # Add print only r code
    return prompt

def chatgpt_code (prompt2, openai_api_key):
    # Create the R script
    filename = str(uuid.uuid4())
    # ans = gpt_code(prompt2, openai_api_key)
    with open(filename + '.R', 'w') as fi:
        fi.write(gpt_code(prompt2, openai_api_key) + '\n')

    # Run the R script and capture the output
    result = subprocess.run(['Rscript', filename + '.R'], capture_output=True)
    temp = str(result.stdout.decode())
    err = str(result.stderr.decode())
    
    # Parse result (David 2 Feb)
    print(temp)
    regex = re.search("\[.\](.|\n)*", temp)
    if not regex:
        temp = ''

#     if len(temp) > 0:
#         Check validity (Future)
    # Error handling (David 2 Feb)
    # David (7 Feb) Extract NO_OF_RETRIES
    
    NO_OF_RETRIES = 3
    counter = 0
    while len(temp) == 0 and counter < NO_OF_RETRIES:
        regex = re.search("\[.\](.|\n)*", temp)
        if not regex:
            temp = ''
        if len(err) > 0:
            if "No such file or directory" in err:
                split_string = err.split(" ")
                missing_file = ""
                for i in split_string:
                    if i[0] == "'" and i[-1] == "'":
                        missing_file = i[1:-1]
                # Might have to try 3 times and correct file
                return missing_file + "cannot be found"
            
            if "there is no package called " in err:
                split_string = err.split(" ")
                missing_package = ""
                for i in split_string:
                    if i[0] == "'" and i[-1] == "'":
                        missing_package = i[1:-1]
                new_code_prompt = install_package_prompt(filename, missing_package)
                new_ans = openai_create(new_code_prompt, openai_api_key)
                new_filename = str(uuid.uuid4())
                with open(new_filename+'.R', 'w') as file:
                    file.write(answer + '\n')
                result = subprocess.run(['Rscript', new_filename + '.R'], capture_output=True)
                temp = str(result.stdout.decode())
                err = str(result.stderr.decode())

        if len(err) == 0:
            new_code_prompt = rewrite_code_prompt(filename)
            new_ans = openai_create(new_code_prompt, openai_api_key)
            new_filename = str(uuid.uuid4())
            with open(new_filename+'.R', 'w') as file:
                file.write(answer + '\n')
            result = subprocess.run(['Rscript', new_filename + '.R'], capture_output=True)
            temp = str(result.stdout.decode())
            err = str(result.stderr.decode())

        counter += 1
    
    if len(temp) == 0:
        return "<h2> Please Try Again! </h2>"    

    result = regex.group(0)
    
    r2 = ("\nOutput:\n" + result)
    f = open("history.txt", "a")
    
    f.write(prompt2 + ";\n")
    f.write(r2 + ".\n")
    return (r2)

# %%
# open_api_key = "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"
# chatgpt_code ("is the wind good for corn", open_api_key)

# %%
# UI HTML

block = gr.Blocks(css=".gradio-container {background-color: lightgray}")

with block:
    with gr.Row():
        title = gr.Markdown("""<h3><center>Ask me anything!</center></h3>""")

        openai_api_key_textbox = gr.Textbox(placeholder="Paste your OpenAI API key (sk-...)",
                                            show_label=False, lines=1, type='password')

    answer_html = gr.Markdown()

    request = gr.Textbox(label="Question:",
                         placeholder="Ex: Are the conditions suitable for planting corn?")
    with gr.Row():
        gpt_only = gr.Button(value="GPT Only", variant="secondary").style(full_width=False)
        gpt_pal = gr.Button(value="GPT w/SQL", variant="secondary").style(full_width=False)
        gpt_r = gr.Button(value="GPT w/R", variant="secondary").style(full_width=False)
        wolf_alpha = gr.Button(value="Wolfram Alpha", variant="secondary").style(full_width=False)
        history = gr.Button(value="History", variant="secondary").style(full_width=False)
        clear_hist = gr.Button(value="Clear History", variant="secondary").style(full_width=False)

    openai_api_key_state = gr.State()
    pal_chain_state = gr.State()

    gpt_only.click(calc_gpt_only, inputs=[request, openai_api_key_state], outputs=[answer_html])
    gpt_pal.click(calc_gpt_sql, inputs=[request, pal_chain_state], outputs=[answer_html])
    gpt_r.click (chatgpt_code, inputs=[request, openai_api_key_state], outputs=[answer_html])
    wolf_alpha.click(wolfAlphaGpt3Complete, inputs=[request, openai_api_key_state], outputs=[answer_html])
    history.click(get_history, inputs=[], outputs=[answer_html])
    clear_hist.click(clear_history, inputs=[], outputs=[answer_html])
    
    openai_api_key_textbox.change(set_openai_api_key,
                                  inputs=[openai_api_key_textbox, openai_api_key_state, pal_chain_state],
                                  outputs=[openai_api_key_state, pal_chain_state])

# %%
block.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Calories in a burger 1 hamburger | amount | 1 hamburger | total calories421 Cal (dietary Calories)1.8 MJ (megajoules)1.8×10^6 J (joules)1.8×10^13 ergs
#  (unit officially deprecated)420 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)420 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | hamburger | 421 Cal | 21% | (364 to 501) Cal
# fat calories | hamburger | 186 Cal | | (159 to 241) Cal
# 2) Calories in an egg 2 egg | amount | 1 egg | total calories110 Cal (dietary Calories)460 kJ (kilojoules)0.46 MJ (megajoules)460000 J (joules)4.6×10^12 ergs
#  (unit officially deprecated)110 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | egg | 55 Cal | 3% | (48 to 68) Cal
# fat calories | egg | 35 Cal | | (33 to 37) Cal
# 3) Calories in a cake 3 cake | amount | 80 grams | total calories830 Cal (dietary Calories)3.5 MJ (megajoules)3.5×10^6 J (joules)3.5×10^13 ergs
#  (unit officially deprecated)830 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)830 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | cake | 277 Cal | 14% | (211 to 311) Cal
# fat calories | cake | 104 Cal | | (8.1 to 140) Cal
# 4) Fat content in a burger 4 hamburger | amount | 1 hamburger | total fat81 grams0.081 kg (kilograms)0.18 lb (pounds)2.8 oz (ounces)| | mean value | % daily value | range
# total fat | hamburger | 20 g | 31% | (16 to 27) g
# saturated fat | hamburger | 7.1 g | 36% | (5.7 to 9.9) g
# trans fat | hamburger | 916 mg | | 916 mg
# 5) Fat content in an egg 5 egg | amount | 1 egg | total fat20 grams0.02 kg (kilograms)0.71 oz (ounces)| | mean value | % daily value | range
# total fat | egg | 4 g | 6% | (3.3 to 5.2) g
# saturated fat | egg | 1.2 g | 6% | (1.1 to 1.5) g
# trans fat | egg | 228 mg | | (208 to 247) mg
# 6) Fat content in a cake 6 cake | amount | 80 grams | total fat62 grams0.062 kg (kilograms)0.14 lb (pounds)2.2 oz (ounces)≈ 1.1 × US large egg minimum average mass (per dozen) ( ≈ 24 oz/doz. )| | mean value | % daily value | range
# total fat | cake | 10 g | 16% | (0.96 to 16) g
# saturated fat | cake | 3.2 g | 16% | (0.21 to 9.2) g
# 7) Protein content in a burger 7 hamburger | amount | 1 hamburger | protein150 grams0.15 kg (kilograms)0.33 lb (pounds)5.3 oz (ounces)| | mean value | % daily value | range
# protein | hamburger | 22 g | 43% | (18 to 27) g
# 8) Protein content in an egg 8 egg | amount | 1 egg | protein33 grams0.033 kg (kilograms)1.2 oz (ounces)| | mean value | % daily value | range
# protein | egg | 4.1 g | 8% | (3.5 to 4.7) g
# 9) Protein content in a cake 9 cake | amount | 80 grams | protein34 grams0.034 kg (kilograms)1.2 oz (ounces)| | mean value | % daily value | range
# protein | cake | 3.8 g | 8% | (1.9 to 5.8) g
#
# .
#
# Based on the data, I would not recommend eating either an egg or cake for dessert. The burger I just ate contains 421 calories, 186 fat calories, and 22g of protein. An egg contains 55 calories, 35 fat calories, and 4.1g of protein. A cake contains 277 calories, 104 fat calories, and 3.8g of protein.
#
# Given my age, weight, and the amount of calories and fat I have already consumed, eating either an egg or cake for dessert would not be a healthy choice. Eating either of these would add too many calories and fat to my diet, and not enough protein.
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Calories in a burger 1 hamburger | amount | 1 hamburger | total calories421 Cal (dietary Calories)1.8 MJ (megajoules)1.8×10^6 J (joules)1.8×10^13 ergs
#  (unit officially deprecated)420 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)420 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | hamburger | 421 Cal | 21% | (364 to 501) Cal
# fat calories | hamburger | 186 Cal | | (159 to 241) Cal
# 2) Calories in an egg 2 egg | amount | 1 egg | total calories110 Cal (dietary Calories)460 kJ (kilojoules)0.46 MJ (megajoules)460000 J (joules)4.6×10^12 ergs
#  (unit officially deprecated)110 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | egg | 55 Cal | 3% | (48 to 68) Cal
# fat calories | egg | 35 Cal | | (33 to 37) Cal
# 3) Calories in a cake 3 cake | amount | 80 grams | total calories830 Cal (dietary Calories)3.5 MJ (megajoules)3.5×10^6 J (joules)3.5×10^13 ergs
#  (unit officially deprecated)830 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)830 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | cake | 277 Cal | 14% | (211 to 311) Cal
# fat calories | cake | 104 Cal | | (8.1 to 140) Cal
# 4) Fat content in a burger 4 hamburger | amount | 1 hamburger | total fat81 grams0.081 kg (kilograms)0.18 lb (pounds)2.8 oz (ounces)| | mean value | % daily value | range
# total fat | hamburger | 20 g | 31% | (16 to 27) g
# saturated fat | hamburger | 7.1 g | 36% | (5.7 to 9.9) g
# trans fat | hamburger | 916 mg | | 916 mg
# 5) Fat content in an egg 5 egg | amount | 1 egg | total fat20 grams0.02 kg (kilograms)0.71 oz (ounces)| | mean value | % daily value | range
# total fat | egg | 4 g | 6% | (3.3 to 5.2) g
# saturated fat | egg | 1.2 g | 6% | (1.1 to 1.5) g
# trans fat | egg | 228 mg | | (208 to 247) mg
# 6) Fat content in a cake 6 cake | amount | 80 grams | total fat62 grams0.062 kg (kilograms)0.14 lb (pounds)2.2 oz (ounces)≈ 1.1 × US large egg minimum average mass (per dozen) ( ≈ 24 oz/doz. )| | mean value | % daily value | range
# total fat | cake | 10 g | 16% | (0.96 to 16) g
# saturated fat | cake | 3.2 g | 16% | (0.21 to 9.2) g
# 7) Protein content in a burger 7 hamburger | amount | 1 hamburger | protein150 grams0.15 kg (kilograms)0.33 lb (pounds)5.3 oz (ounces)| | mean value | % daily value | range
# protein | hamburger | 22 g | 43% | (18 to 27) g
# 8) Protein content in an egg 8 egg | amount | 1 egg | protein33 grams0.033 kg (kilograms)1.2 oz (ounces)| | mean value | % daily value | range
# protein | egg | 4.1 g | 8% | (3.5 to 4.7) g
# 9) Protein content in a cake 9 cake | amount | 80 grams | protein34 grams0.034 kg (kilograms)1.2 oz (ounces)| | mean value | % daily value | range
# protein | cake | 3.8 g | 8% | (1.9 to 5.8) g
#
# .
#
# Based on the data, I would not recommend eating either an egg or cake for dessert. The burger I just ate had 421 calories, 186 fat calories, and 22g of protein. An egg has 55 calories, 35 fat calories, and 4.1g of protein. A cake has 277 calories, 104 fat calories, and 3.8g of protein.
#
# Given my age, weight, and the fact that I just ate a burger, I should not eat either an egg or cake for dessert. Eating either of these would add too many calories and fat to my diet. Instead, I should opt for a healthier dessert option such as a piece of fruit or a yogurt.
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Calories in a burger 1 hamburger | amount | 1 hamburger | total calories421 Cal (dietary Calories)1.8 MJ (megajoules)1.8×10^6 J (joules)1.8×10^13 ergs
#  (unit officially deprecated)420 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)420 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | hamburger | 421 Cal | 21% | (364 to 501) Cal
# fat calories | hamburger | 186 Cal | | (159 to 241) Cal
# 2) Calories in an egg 2 egg | amount | 1 egg | total calories110 Cal (dietary Calories)460 kJ (kilojoules)0.46 MJ (megajoules)460000 J (joules)4.6×10^12 ergs
#  (unit officially deprecated)110 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | egg | 55 Cal | 3% | (48 to 68) Cal
# fat calories | egg | 35 Cal | | (33 to 37) Cal
# 3) Calories in a cake 3 cake | amount | 80 grams | total calories830 Cal (dietary Calories)3.5 MJ (megajoules)3.5×10^6 J (joules)3.5×10^13 ergs
#  (unit officially deprecated)830 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)830 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | cake | 277 Cal | 14% | (211 to 311) Cal
# fat calories | cake | 104 Cal | | (8.1 to 140) Cal
# 4) Fat content in a burger 4 hamburger | amount | 1 hamburger | total fat81 grams0.081 kg (kilograms)0.18 lb (pounds)2.8 oz (ounces)| | mean value | % daily value | range
# total fat | hamburger | 20 g | 31% | (16 to 27) g
# saturated fat | hamburger | 7.1 g | 36% | (5.7 to 9.9) g
# trans fat | hamburger | 916 mg | | 916 mg
# 5) Fat content in an egg 5 egg | amount | 1 egg | total fat20 grams0.02 kg (kilograms)0.71 oz (ounces)| | mean value | % daily value | range
# total fat | egg | 4 g | 6% | (3.3 to 5.2) g
# saturated fat | egg | 1.2 g | 6% | (1.1 to 1.5) g
# trans fat | egg | 228 mg | | (208 to 247) mg
# 6) Fat content in a cake 6 cake | amount | 80 grams | total fat62 grams0.062 kg (kilograms)0.14 lb (pounds)2.2 oz (ounces)≈ 1.1 × US large egg minimum average mass (per dozen) ( ≈ 24 oz/doz. )| | mean value | % daily value | range
# total fat | cake | 10 g | 16% | (0.96 to 16) g
# saturated fat | cake | 3.2 g | 16% | (0.21 to 9.2) g
# 7) Protein content in a burger 7 hamburger | amount | 1 hamburger | protein150 grams0.15 kg (kilograms)0.33 lb (pounds)5.3 oz (ounces)| | mean value | % daily value | range
# protein | hamburger | 22 g | 43% | (18 to 27) g
# 8) Protein content in an egg 8 egg | amount | 1 egg | protein33 grams0.033 kg (kilograms)1.2 oz (ounces)| | mean value | % daily value | range
# protein | egg | 4.1 g | 8% | (3.5 to 4.7) g
# 9) Protein content in a cake 9 cake | amount | 80 grams | protein34 grams0.034 kg (kilograms)1.2 oz (ounces)| | mean value | % daily value | range
# protein | cake | 3.8 g | 8% | (1.9 to 5.8) g
#
# .
#
# Based on the data, I would not recommend eating either an egg or cake for dessert. The burger I just ate had 421 calories, 186 fat calories, and 22g of protein. An egg has 55 calories, 35 fat calories, and 4.1g of protein. A cake has 277 calories, 104 fat calories, and 3.8g of protein.
#
# Given my age, weight, and the fact that I just ate a burger, I should not eat either an egg or cake for dessert. Eating either of these would add too many calories and fat to my diet. Instead, I should opt for a healthier dessert option such as a piece of fruit or a yogurt.

# %%
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
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/n5/s57r8x5d4bb__yypzdfspcsh0000gn/T/ipykernel_54250/3245048919.py in <module>
# ----> 1 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
#
# NameError: name 'sk' is not defined

# %% [markdown]
# Addition to prompt: Be specific about the type of food in the queries, break recipes down into their individual components and use the following format to generate questions: What is the amount of nutrition x in food y
# 1. More general questions such as: "What type of food should I eat if I am diabetic / want to lose weight / have vitamin deficiencies etc
# 2. User specific questions: "I am x years old, male/female, weighing x, what type of foods should I eat" /n
# 3. Recipe questions: 'How do i make french toast' <- includes nutrional information /n
# 4. Comparison questions: 'Which is healthier beef or chicken' /n
# 5. Food substitution questions: 'What is a good substitute for butter
# Also, answers will now include data from Wolfman Alpha to support the answers

# %%
I am 40 years old, 50 kg, I just ate a burger. Should I eat an egg or cake for dessert

# %%
I am diabetic, can I eat two donuts

# %%
What are the average temperatures?  Are the temperatures appropriate for growing corn?

# %%
What are the average temperatures for growing corn?

# %%
What is the average humidity?

# %%
 Is the humidity  in the data appropriate for growing corn?

# %%
What humidity is ideal for growing corn?

# %%
print ("Based on the data, a balanced lunch for a 40 year old should include a combination of foods that provide a variety of nutrients and calories. A good option would be a sandwich with two slices of whole wheat bread, two slices of turkey, lettuce, tomato, and mayonnaise, a salad with two cups of lettuce, one-half cup of tomatoes, one-fourth cup of cucumbers, one-fourth cup of carrots, and one-fourth cup of olive oil, and a bowl of vegetable soup with one cup of carrots, one cup of celery, one cup of onions, one cup of potatoes, and one cup of broth. This combination of foods will provide a variety of nutrients and calories to help maintain your weight.")
# Out:
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Calories in a burger 1 hamburger | amount | 1 hamburger | total calories421 Cal (dietary Calories)1.8 MJ (megajoules)1.8×10^6 J (joules)1.8×10^13 ergs
#  (unit officially deprecated)420 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)420 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | hamburger | 421 Cal | 21% | (364 to 501) Cal
# fat calories | hamburger | 186 Cal | | (159 to 241) Cal
# 2) Calories in an egg 2 egg | amount | 1 egg | total calories110 Cal (dietary Calories)460 kJ (kilojoules)0.46 MJ (megajoules)460000 J (joules)4.6×10^12 ergs
#  (unit officially deprecated)110 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | egg | 55 Cal | 3% | (48 to 68) Cal
# fat calories | egg | 35 Cal | | (33 to 37) Cal
# 3) Calories in a cake 3 cake | amount | 80 grams | total calories830 Cal (dietary Calories)3.5 MJ (megajoules)3.5×10^6 J (joules)3.5×10^13 ergs
#  (unit officially deprecated)830 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)830 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | cake | 277 Cal | 14% | (211 to 311) Cal
# fat calories | cake | 104 Cal | | (8.1 to 140) Cal
# 4) Fat content in a burger 4 hamburger | amount | 1 hamburger | total fat81 grams0.081 kg (kilograms)0.18 lb (pounds)2.8 oz (ounces)| | mean value | % daily value | range
# total fat | hamburger | 20 g | 31% | (16 to 27) g
# saturated fat | hamburger | 7.1 g | 36% | (5.7 to 9.9) g
# trans fat | hamburger | 916 mg | | 916 mg
# 5) Fat content in an egg 5 egg | amount | 1 egg | total fat20 grams0.02 kg (kilograms)0.71 oz (ounces)| | mean value | % daily value | range
# total fat | egg | 4 g | 6% | (3.3 to 5.2) g
# saturated fat | egg | 1.2 g | 6% | (1.1 to 1.5) g
# trans fat | egg | 228 mg | | (208 to 247) mg
# 6) Fat content in a cake 6 cake | amount | 80 grams | total fat62 grams0.062 kg (kilograms)0.14 lb (pounds)2.2 oz (ounces)≈ 1.1 × US large egg minimum average mass (per dozen) ( ≈ 24 oz/doz. )| | mean value | % daily value | range
# total fat | cake | 10 g | 16% | (0.96 to 16) g
# saturated fat | cake | 3.2 g | 16% | (0.21 to 9.2) g
# 7) Protein content in a burger 7 hamburger | amount | 1 hamburger | protein150 grams0.15 kg (kilograms)0.33 lb (pounds)5.3 oz (ounces)| | mean value | % daily value | range
# protein | hamburger | 22 g | 43% | (18 to 27) g
# 8) Protein content in an egg 8 egg | amount | 1 egg | protein33 grams0.033 kg (kilograms)1.2 oz (ounces)| | mean value | % daily value | range
# protein | egg | 4.1 g | 8% | (3.5 to 4.7) g
# 9) Protein content in a cake 9 cake | amount | 80 grams | protein34 grams0.034 kg (kilograms)1.2 oz (ounces)| | mean value | % daily value | range
# protein | cake | 3.8 g | 8% | (1.9 to 5.8) g
#
# .
#
# Based on the data, I would not recommend eating either an egg or cake for dessert. The burger I just ate had 421 calories, 186 fat calories, and 22g of protein. An egg has 55 calories, 35 fat calories, and 4.1g of protein. A cake has 277 calories, 104 fat calories, and 3.8g of protein. Eating either of these would add too many calories and fat to my meal. Instead, I would recommend eating a piece of fruit or a small serving of yogurt for dessert.
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Calories in a burger 1 hamburger | amount | 1 hamburger | total calories421 Cal (dietary Calories)1.8 MJ (megajoules)1.8×10^6 J (joules)1.8×10^13 ergs
#  (unit officially deprecated)420 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)420 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | mean value | % daily value | range
# total calories | hamburger | 421 Cal | 21% | (364 to 501) Cal
# fat calories | hamburger | 186 Cal | | (159 to 241) Cal
# 2) Nutritional value of a burger Could not retrieve answer! (Query Failed)
# 3) Calorie intake for a 40 year old 3 average calories consumed per day by adults a (40 years (age))a 40 years 6438 Cal (dietary Calories)
# 4) Healthy lunch options for a 40 year old Could not retrieve answer! (Query Failed)
# 5) Nutritional value of a salad Could not retrieve answer! (Query Failed)
# 6) Calorie content of a sandwich Could not retrieve answer! (Query Failed)
# 7) Nutritional value of a soup Could not retrieve answer! (Query Failed)
# 8) Calorie content of a wrap Could not retrieve answer! (Query Failed)
#
# .
#
# Based on the data, a healthy lunch option for a 40 year old, 50 kg person who just ate a burger would be a salad. A salad typically contains a variety of vegetables, such as lettuce, tomatoes, cucumbers, peppers, and onions, as well as other ingredients such as nuts, seeds, and cheese. A typical salad contains around 200-300 calories, depending on the ingredients. Additionally, salads are a great source of vitamins, minerals, and fiber.
#
# To calculate the calorie content of a sandwich, you would need to know the type of bread, the type of filling, and the amount of each ingredient used. For example, a sandwich made with two slices of whole wheat bread, two slices of cheese, and two slices of deli meat would contain approximately 500 calories.
#
# To calculate the nutritional value of a soup, you would need to know the type of soup, the ingredients used, and the amount of each ingredient used. For example, a cup of vegetable soup made with carrots, celery, onions, and potatoes would contain approximately 100 calories.
#
# To calculate the calorie content of a wrap, you would need to know the type of wrap, the type of filling, and the amount of each ingredient used. For example, a wrap made with a whole wheat tortilla, two slices of cheese, and two slices of deli meat would contain approximately 400 calories.
#
# In conclusion, a healthy lunch option
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Calories in 1 cup boiled peanuts (convert 1 Cal (dietary Calorie) to cups) | boiling point(insufficient data available)
# 2) Calories in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
# 3) Protein in 1 cup boiled peanuts 3 peanut | amount | 1 c (cup)
# type | boiled | protein60 grams0.06 kg (kilograms)0.13 lb (pounds)2.1 oz (ounces)≈ 1.1 × US large egg minimum average mass (per dozen) ( ≈ 24 oz/doz. )| | value | % daily value
# protein | peanut, boiled | 20 g | 40%
# 4) Protein in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
# 5) Fat in 1 cup boiled peanuts 5 peanut | amount | 1 c (cup)
# type | boiled | total fat162 grams0.16 kg (kilograms)0.36 lb (pounds)5.7 oz (ounces)| | value | % daily value
# total fat | peanut, boiled | 32 g | 50%
# saturated fat | peanut, boiled | 4.5 g | 22%
# 6) Fat in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
# 7) Carbohydrates in 1 cup boiled peanuts 7 peanut | amount | 1 c (cup)
# type | boiled | total carbohydrates219 grams0.22 kg (kilograms)0.48 lb (pounds)7.7 oz (ounces)| | value | % daily value
# total carbohydrates | peanut, boiled | 31 g | 10%
# dietary fiber | peanut, boiled | 13 g | 52%
# sugar | peanut, boiled | 3.6 g |
# 8) Carbohydrates in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
#
# .
#
# Based on the data, it appears that boiled peanuts are better for gaining weight than roasted peanuts. Boiled peanuts contain more calories, protein, and fat than roasted peanuts.
#
# 1 cup of boiled peanuts contains approximately 600 calories, 20g of protein, 32g of fat, and 31g of carbohydrates.
#
# In comparison, 1 cup of roasted peanuts contains an unknown amount of calories, protein, fat, and carbohydrates.
#
# Therefore, boiled peanuts are a better option for gaining weight than roasted peanuts.
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
# Status Code: 200
#
# 1) Calories in 1 cup boiled peanuts (convert 1 Cal (dietary Calorie) to cups) | boiling point(insufficient data available)
# 2) Calories in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
# 3) Fat content in 1 cup boiled peanuts 3 peanut | amount | 1 c (cup)
# type | boiled | total fat97 grams0.097 kg (kilograms)0.21 lb (pounds)3.4 oz (ounces)| | value | % daily value
# total fat | peanut, boiled | 32 g | 50%
# saturated fat | peanut, boiled | 4.5 g | 22%
# 4) Fat content in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
# 5) Protein content in 1 cup boiled peanuts 5 peanut | amount | 1 c (cup)
# type | boiled | protein99 grams0.099 kg (kilograms)0.22 lb (pounds)3.5 oz (ounces)| | value | % daily value
# protein | peanut, boiled | 20 g | 40%
# 6) Protein content in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
# 7) Carbohydrate content in 1 cup boiled peanuts 7 peanut | amount | 1 c (cup)
# type | boiled | total carbohydrates219 grams0.22 kg (kilograms)0.48 lb (pounds)7.7 oz (ounces)| | value | % daily value
# total carbohydrates | peanut, boiled | 31 g | 10%
# dietary fiber | peanut, boiled | 13 g | 52%
# sugar | peanut, boiled | 3.6 g |
# 8) Carbohydrate content in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
#
# .
#
# Based on the data, boiled peanuts are better for weight loss than roasted peanuts. Boiled peanuts have a lower calorie content (1 cup boiled peanuts contains 567 calories, compared to 607 calories in 1 cup roasted peanuts), lower fat content (32 grams of fat in 1 cup boiled peanuts, compared to 37 grams of fat in 1 cup roasted peanuts), and higher protein content (20 grams of protein in 1 cup boiled peanuts, compared to 17 grams of protein in 1 cup roasted peanuts). Additionally, boiled peanuts have a lower carbohydrate content (31 grams of carbohydrates in 1 cup boiled peanuts, compared to 34 grams of carbohydrates in 1 cup roasted peanuts).
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Calories in 1 cup boiled peanuts (convert 1 Cal (dietary Calorie) to cups) | boiling point(insufficient data available)
# 2) Calories in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
# 3) Fat content in 1 cup boiled peanuts 3 peanut | amount | 1 c (cup)
# type | boiled | total fat97 grams0.097 kg (kilograms)0.21 lb (pounds)3.4 oz (ounces)| | value | % daily value
# total fat | peanut, boiled | 32 g | 50%
# saturated fat | peanut, boiled | 4.5 g | 22%
# 4) Fat content in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
# 5) Protein content in 1 cup boiled peanuts 5 peanut | amount | 1 c (cup)
# type | boiled | protein99 grams0.099 kg (kilograms)0.22 lb (pounds)3.5 oz (ounces)| | value | % daily value
# protein | peanut, boiled | 20 g | 40%
# 6) Protein content in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
# 7) Carbohydrate content in 1 cup boiled peanuts 7 peanut | amount | 1 c (cup)
# type | boiled | total carbohydrates219 grams0.22 kg (kilograms)0.48 lb (pounds)7.7 oz (ounces)| | value | % daily value
# total carbohydrates | peanut, boiled | 31 g | 10%
# dietary fiber | peanut, boiled | 13 g | 52%
# sugar | peanut, boiled | 3.6 g |
# 8) Carbohydrate content in 1 cup roasted peanuts Could not retrieve answer! (Query Failed)
#
# .
#
# Based on the data provided, boiled peanuts are healthier than roasted peanuts. Boiled peanuts contain fewer calories (1 cup boiled peanuts contains approximately 830 calories, while 1 cup roasted peanuts contains approximately 890 calories), more protein (1 cup boiled peanuts contains approximately 20 grams of protein, while 1 cup roasted peanuts contains approximately 17 grams of protein), and more dietary fiber (1 cup boiled peanuts contains approximately 13 grams of dietary fiber, while 1 cup roasted peanuts contains approximately 9 grams of dietary fiber). Additionally, boiled peanuts contain less fat than roasted peanuts (1 cup boiled peanuts contains approximately 32 grams of fat, while 1 cup roasted peanuts contains approximately 39 grams of fat).
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Average calorie intake for 23 year old  average calories consumed per day by adults (23 years (age))49360 yr Cal (year dietary Calories)6.513×10^15 J s (joule seconds)6.513×10^15 N m s (newton meter seconds)6.176×10^49 ℏ (reduced Planck constants)6.513×10^15 J/Hz (joules per hertz)9.829×10^48 h_90 (conventional Planck constants)
# 2) Calorie expenditure for 30 minutes of jogging, 6mph running |
# time | 30 minutes
# speed | 6 mph (miles per hour)
# age | 2 years
# gender | male
# height | 87 cm (centimeters)
# body weight | 12 kg (kilograms)energy expenditure | 267.8 kJ (kilojoules)
# fat burned | 0.0083 kg (kilograms)
# oxygen consumption | 12.8 L (liters)
# metabolic equivalent | 10 metabolic equivalents
# (estimates based on CDC standards)≈ 3 hours drawing, writing, or painting while standing≈ 26 minutes stationary rowing at 200 watts≈ 1 hour 10 minutes walking at 2.0 mph up a 6% to 15% incline9.656 km/h (kilometers per hour)0.1609 km/min (kilometers per minute)2.682 m/s (meters per second)(0.2286 to 0.2291) lengths of a marathon race/h (lengths of a marathon race per hour)0.1036 h/km (hours per kilometer)6.214 min/km (minutes per kilometer)0.3728 s/m (seconds per meter)(4.365 to 4.374) h/length of a marathon race (hours per length of a marathon race)4.828 km (kilometers)4828 meters(0.1143 to 0.1145) lengths of a marathon race13372 steps30 minutes1800 seconds0.5 hoursrace | finish time | average speed | average pace
# 100 m | 25.9 s | 3.9 m/s | 0.3 s/m
# 400 m | 2 min 2 s | 3.3 m/s | 0.3 s/m
# 1 mi (1.61 km) | 9 min 17 s | 2.9 m/s | 0.3 s/m
# 10 km | 1 h 5 min | 0.15 km/min | 6.49 min/km
# marathon (42.15 to 42.24 km) | 5 h | 0.14 km/min | 7.11 min/km
# (based on Riegel and Cameron models)
# 3) Protein in 2 eggs 3 egg | amount | 2 eggs | protein25 grams0.025 kg (kilograms)0.88 oz (ounces)| | mean value | % daily value | range
# protein | egg | 8.3 g | 17% | (7 to 9.5) g
# 4) Iron in 1 cup of oatmeal 4 oats | amount | 1 c (cup)
# type | cooked with water | regular | iron5.6 mg (milligrams)0.0056 grams5.6×10^-6 kg (kilograms)| | mean value | % daily value | range
# calcium | oats, cooked with water, regular | 14 mg | 1% | 14 mg
# iron | oats, cooked with water, regular | 1.4 mg | 8% | 1.4 mg
# 5) Calcium in 1 cup of milk 5 milk | amount | 1 c (cup) | calcium1940 mg (milligrams)1.9 grams0.0019 kg (kilograms)| | mean value | % daily value | range
# calcium | milk | 387 mg | 39% | (259 to 742) mg
# iron | milk | 272 μg | 2% | (77 to 742) μg
# 6) Fiber in 1 cup of blueberries 6 blueberry | amount | 1 c (cup) | dietary fiber21 grams0.021 kg (kilograms)0.75 oz (ounces)| | value | % daily value
# total carbohydrates | blueberry | 21 g | 7%
# dietary fiber | blueberry | 3.6 g | 14%
# sugar | blueberry | 15 g |
# 7) Fat in 1 tablespoon of peanut butter 7 peanut butter | amount | 1 tbsp (tablespoon) | total fat57 grams0.057 kg (kilograms)0.13 lb (pounds)2 oz (ounces)≈ US large egg minimum average mass (per dozen) ( ≈ 24 oz/doz. )| | mean value | % daily value | range
# total fat | peanut butter | 8.2 g | 13% | (8 to 8.7) g
# saturated fat | peanut butter | 1.5 g | 7% | (1.2 to 1.7) g
# trans fat | peanut butter | 6 mg | | 6 mg
#
# .
#
# A good breakfast for someone who is 23 years old and trying to lose weight would be two eggs, one cup of oatmeal, one cup of milk, one cup of blueberries, and one tablespoon of peanut butter. This breakfast provides a good balance of protein, iron, calcium, fiber, and fat.
#
# Calorie Intake: 49360 yr Cal (year dietary Calories)
# Calorie Expenditure: 267.8 kJ (kilojoules)
#
# Protein: 2 eggs = 25 grams = 0.025 kg = 0.88 oz
# Iron: 1 cup of oatmeal = 5.6 mg = 0.0056 grams = 5.6x10^-6 kg
# Calcium: 1 cup of milk = 1940 mg = 1.9 grams = 0.0019 kg
# Fiber: 1 cup of blueberries = 21 grams = 0.021 kg = 0.75 oz
# Fat: 1 tablespoon of peanut butter = 57 grams = 0.057 kg = 0.13 lb = 2 oz
#
# This breakfast provides a total of 49360 - 267.8 = 49092.2 yr Cal (year dietary Calories) of energy, 25 grams of protein, 5.6 mg of iron, 1940 mg of calcium, 21 grams of fiber, and 57 grams of fat. This breakfast is a good balance of nutrients and provides enough energy to help you lose weight.
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Calories in 1 serving of lasagna 1 Amy's vegetable lasagna | amount | 1 Package | total calories310 Cal (dietary Calories)1.3 MJ (megajoules)1.3×10^6 J (joules)1.3×10^13 ergs
#  (unit officially deprecated)310 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)310 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | value | % daily value
# total calories | Amy's vegetable lasagna | 310 Cal | 15%
# fat calories | Amy's vegetable lasagna | 110 Cal |
# 2) Calories in 1 serving of aglio olio pasta Could not retrieve answer! (Query Failed)
# 3) Fat content in 1 serving of lasagna 3 Amy's vegetable lasagna | amount | 1 Package | total fat36 grams0.036 kg (kilograms)1.3 oz (ounces)| | value | % daily value
# total fat | Amy's vegetable lasagna | 12 g | 18%
# saturated fat | Amy's vegetable lasagna | 4.5 g | 22%
# trans fat | Amy's vegetable lasagna | 0 g |
# 4) Fat content in 1 serving of aglio olio pasta Could not retrieve answer! (Query Failed)
# 5) Carbohydrate content in 1 serving of lasagna 5 Amy's vegetable lasagna | amount | 1 Package | total carbohydrates170 grams0.17 kg (kilograms)0.39 lb (pounds)6.2 oz (ounces)| | value | % daily value
# total carbohydrates | Amy's vegetable lasagna | 35 g | 12%
# sugar | Amy's vegetable lasagna | 5 g |
# 6) Carbohydrate content in 1 serving of aglio olio pasta Could not retrieve answer! (Query Failed)
# 7) Protein content in 1 serving of lasagna 7 Amy's vegetable lasagna | amount | 1 Package | protein110 grams0.11 kg (kilograms)0.25 lb (pounds)3.9 oz (ounces)| | value | % daily value
# protein | Amy's vegetable lasagna | 16 g | 32%
# 8) Protein content in 1 serving of aglio olio pasta Could not retrieve answer! (Query Failed)
#
# .
#
# Without the data for aglio olio pasta, it is not possible to determine which pasta is better. Lasagna has 310 calories, 36 grams of fat, 170 grams of carbohydrates, and 110 grams of protein per serving. However, without the data for aglio olio pasta, it is not possible to compare the two pastas.
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Calories in 1 serving of lasagna 1 Amy's vegetable lasagna | amount | 1 Package | total calories310 Cal (dietary Calories)1.3 MJ (megajoules)1.3×10^6 J (joules)1.3×10^13 ergs
#  (unit officially deprecated)310 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)310 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | value | % daily value
# total calories | Amy's vegetable lasagna | 310 Cal | 15%
# fat calories | Amy's vegetable lasagna | 110 Cal |
# 2) Protein in 1 serving of lasagna 2 Amy's vegetable lasagna | amount | 1 Package | protein32 grams0.032 kg (kilograms)1.1 oz (ounces)| | value | % daily value
# protein | Amy's vegetable lasagna | 16 g | 32%
# 3) Fat in 1 serving of lasagna 3 Amy's vegetable lasagna | amount | 1 Package | total fat36 grams0.036 kg (kilograms)1.3 oz (ounces)| | value | % daily value
# total fat | Amy's vegetable lasagna | 12 g | 18%
# saturated fat | Amy's vegetable lasagna | 4.5 g | 22%
# trans fat | Amy's vegetable lasagna | 0 g |
# 4) Carbohydrates in 1 serving of lasagna 4 Amy's vegetable lasagna | amount | 1 Package | total carbohydrates140 grams0.14 kg (kilograms)0.31 lb (pounds)4.9 oz (ounces)| | value | % daily value
# total carbohydrates | Amy's vegetable lasagna | 35 g | 12%
# sugar | Amy's vegetable lasagna | 5 g |
# 5) Calories in 1 serving of bolognese Could not retrieve answer! (Query Failed)
# 6) Protein in 1 serving of bolognese Could not retrieve answer! (Query Failed)
# 7) Fat in 1 serving of bolognese Could not retrieve answer! (Query Failed)
# 8) Carbohydrates in 1 serving of bolognese Could not retrieve answer! (Query Failed)
#
# .
#
# Based on the data provided, it is not possible to determine which dish is better, lasagna or bolognese. Without the nutritional information for bolognese, it is not possible to compare the two dishes.
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Calories in 1 cup of lasagna 1 Michael Angelo's vegetable lasagna | amount | 1 c (cup) | total calories290 Cal (dietary Calories)1.2 MJ (megajoules)1.2×10^6 J (joules)1.2×10^13 ergs
#  (unit officially deprecated)290 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)290 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | value | % daily value
# total calories | Michael Angelo's vegetable lasagna | 290 Cal | 15%
# fat calories | Michael Angelo's vegetable lasagna | 110 Cal |
# 2) Protein in 1 cup of lasagna 2 Michael Angelo's vegetable lasagna | amount | 1 c (cup) | protein38 grams0.038 kg (kilograms)1.3 oz (ounces)| | value | % daily value
# protein | Michael Angelo's vegetable lasagna | 19 g | 38%
# 3) Fat in 1 cup of lasagna 3 Michael Angelo's vegetable lasagna | amount | 1 c (cup) | total fat36 grams0.036 kg (kilograms)1.3 oz (ounces)| | value | % daily value
# total fat | Michael Angelo's vegetable lasagna | 12 g | 18%
# saturated fat | Michael Angelo's vegetable lasagna | 7 g | 35%
# trans fat | Michael Angelo's vegetable lasagna | 0 g |
# 4) Carbs in 1 cup of lasagna 4 Michael Angelo's vegetable lasagna | amount | 1 c (cup) | total carbohydrates112 grams0.11 kg (kilograms)0.25 lb (pounds)4 oz (ounces)| | value | % daily value
# total carbohydrates | Michael Angelo's vegetable lasagna | 28 g | 9%
# sugar | Michael Angelo's vegetable lasagna | 7 g |
# 5) Calories in 1 cup of chicken rice 5 Uncle Ben's roasted chicken Ready Rice | amount | 1 c (cup) | total calories1052 Cal (dietary Calories)4.4 MJ (megajoules)4.4×10^6 J (joules)4.4×10^13 ergs
#  (unit officially deprecated)| | value | % daily value
# total calories | Uncle Ben's roasted chicken Ready Rice | 210 Cal | 11%
# fat calories | Uncle Ben's roasted chicken Ready Rice | 30 Cal |
# 6) Protein in 1 cup of chicken rice 6 Uncle Ben's roasted chicken Ready Rice | amount | 1 c (cup) | protein24 grams0.024 kg (kilograms)0.85 oz (ounces)| | value | % daily value
# protein | Uncle Ben's roasted chicken Ready Rice | 4 g | 8%
# 7) Fat in 1 cup of chicken rice 7 Uncle Ben's roasted chicken Ready Rice | amount | 1 c (cup) | total fat21 grams0.021 kg (kilograms)0.74 oz (ounces)| | value | % daily value
# total fat | Uncle Ben's roasted chicken Ready Rice | 3 g | 5%
# saturated fat | Uncle Ben's roasted chicken Ready Rice | 0 g | 0%
# trans fat | Uncle Ben's roasted chicken Ready Rice | 0 g |
# 8) Carbs in 1 cup of chicken rice 8 Uncle Ben's roasted chicken Ready Rice | amount | 1 c (cup) | total carbohydrates337 grams0.34 kg (kilograms)0.74 lb (pounds)12 oz (ounces)| | value | % daily value
# total carbohydrates | Uncle Ben's roasted chicken Ready Rice | 42 g | 14%
# sugar | Uncle Ben's roasted chicken Ready Rice | 1 g |
#
# .
#
# Based on the data, lasagna is better than chicken rice. Lasagna has 290 calories per cup, while chicken rice has 1052 calories per cup. Lasagna also has 38 grams of protein per cup, while chicken rice has only 24 grams of protein per cup. Lasagna has 12 grams of fat per cup, while chicken rice has 21 grams of fat per cup. Lasagna has 28 grams of carbohydrates per cup, while chicken rice has 42 grams of carbohydrates per cup. Therefore, lasagna is a better choice than chicken rice.
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# Status Code: 200
#
# 1) Calories in 1 cup of lasagna 1 Michael Angelo's vegetable lasagna | amount | 1 c (cup) | total calories290 Cal (dietary Calories)1.2 MJ (megajoules)1.2×10^6 J (joules)1.2×10^13 ergs
#  (unit officially deprecated)290 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)290 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | value | % daily value
# total calories | Michael Angelo's vegetable lasagna | 290 Cal | 15%
# fat calories | Michael Angelo's vegetable lasagna | 110 Cal |
# 2) Calories in 1 cup of chicken rice 2 Uncle Ben's roasted chicken Ready Rice | amount | 1 c (cup) | total calories421 Cal (dietary Calories)1.8 MJ (megajoules)1.8×10^6 J (joules)1.8×10^13 ergs
#  (unit officially deprecated)420 kcal_th (thermochemical kilocalories)
#  (unit officially deprecated)420 kcal_IT (kilocalories (International Steam Table 1956))
#  (unit officially deprecated)| | value | % daily value
# total calories | Uncle Ben's roasted chicken Ready Rice | 210 Cal | 11%
# fat calories | Uncle Ben's roasted chicken Ready Rice | 30 Cal |
# 3) Fat content in 1 cup of lasagna 3 Michael Angelo's vegetable lasagna | amount | 1 c (cup) | total fat36 grams0.036 kg (kilograms)1.3 oz (ounces)| | value | % daily value
# total fat | Michael Angelo's vegetable lasagna | 12 g | 18%
# saturated fat | Michael Angelo's vegetable lasagna | 7 g | 35%
# trans fat | Michael Angelo's vegetable lasagna | 0 g |
# 4) Fat content in 1 cup of chicken rice 4 Uncle Ben's roasted chicken Ready Rice | amount | 1 c (cup) | total fat12 grams0.012 kg (kilograms)0.42 oz (ounces)| | value | % daily value
# total fat | Uncle Ben's roasted chicken Ready Rice | 3 g | 5%
# saturated fat | Uncle Ben's roasted chicken Ready Rice | 0 g | 0%
# trans fat | Uncle Ben's roasted chicken Ready Rice | 0 g |
# 5) Carbohydrates in 1 cup of lasagna 5 Michael Angelo's vegetable lasagna | amount | 1 c (cup) | total carbohydrates140 grams0.14 kg (kilograms)0.31 lb (pounds)4.9 oz (ounces)| | value | % daily value
# total carbohydrates | Michael Angelo's vegetable lasagna | 28 g | 9%
# sugar | Michael Angelo's vegetable lasagna | 7 g |
# 6) Carbohydrates in 1 cup of chicken rice 6 Uncle Ben's roasted chicken Ready Rice | amount | 1 c (cup) | total carbohydrates253 grams0.25 kg (kilograms)0.56 lb (pounds)8.9 oz (ounces)| | value | % daily value
# total carbohydrates | Uncle Ben's roasted chicken Ready Rice | 42 g | 14%
# sugar | Uncle Ben's roasted chicken Ready Rice | 1 g |
# 7) Protein in 1 cup of lasagna 7 Michael Angelo's vegetable lasagna | amount | 1 c (cup) | protein133 grams0.13 kg (kilograms)0.29 lb (pounds)4.7 oz (ounces)| | value | % daily value
# protein | Michael Angelo's vegetable lasagna | 19 g | 38%
# 8) Protein in 1 cup of chicken rice 8 Uncle Ben's roasted chicken Ready Rice | amount | 1 c (cup) | protein32 grams0.032 kg (kilograms)1.1 oz (ounces)| | value | % daily value
# protein | Uncle Ben's roasted chicken Ready Rice | 4 g | 8%
#
# .
#
# Based on the data, if I want to lose weight, chicken rice is better than lasagna. Lasagna has 290 calories, 110 fat calories, 36 grams of total fat, and 133 grams of protein. Chicken rice has 210 calories, 30 fat calories, 12 grams of total fat, and 32 grams of protein.
#
# Calorie Difference: Lasagna has 80 more calories than chicken rice.
# Fat Difference: Lasagna has 24 more grams of fat than chicken rice.
# Protein Difference: Lasagna has 101 more grams of protein than chicken rice.
#
# Therefore, chicken rice is a better option for weight loss since it has fewer calories, less fat, and less protein than lasagna.
